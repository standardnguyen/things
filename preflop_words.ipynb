Nge, Oge, Pge, Qge, Rge, Sge, Tge, Uge, Vge, Wge, Xge, Yge, Zge
Aīm, Bīm, Cīm, Dīm, Eīm, Fīm, Gīm, Hīm, Iīm, Jīm, Kīm, Līm, Mīm
Nre, Ore, Pre, Qre, Rre, Sre, Tre, Ure, Vre, Wre, Xre, Yre, Zre
Aīn, Bīn, Cīn, Dīn, Eīn, Fīn, Gīn, Hīn, Iīn, Jīn, Kīn, Līn, Mīn
Aēm, Bēm, Cēm, Dēm, Eēm, Fēm, Gēm, Hēm, Iēm, Jēm, Kēm, Lēm, Mēm
Aum, Bum, Cum, Dum, Eum, Fum, Gum, Hum, Ium, Jum, Kum, Lum, Mum
Aām, Bām, Cām, Dām, Eām, Fām, Gām, Hām, Iām, Jām, Kām, Lām, Mām
Nme, Ome, Pme, Qme, Rme, Sme, Tme, Ume, Vme, Wme, Xme, Yme, Zme
Aom, Bom, Com, Dom, Eom, Fom, Gom, Hom, Iom, Jom, Kom, Lom, Mom
Aēn, Bēn, Cēn, Dēn, Eēn, Fēn, Gēn, Hēn, Iēn, Jēn, Kēn, Lēn, Mēn
Aun, Bun, Cun, Dun, Eun, Fun, Gun, Hun, Iun, Jun, Kun, Lun, Mun
Aān, Bān, Cān, Dān, Eān, Fān, Gān, Hān, Iān, Jān, Kān, Lān, Mān
Aon, Bon, Con, Don, Eon, Fon, Gon, Hon, Ion, Jon, Kon, Lon, Mon
Ain, Bin, Cin, Din, Ein, Fin, Gin, Hin, Iin, Jin, Kin, Lin, Min'''

# %%
combos = {i+1 : { "words" : words} for i, words in enumerate(words.split("\n"))}
# combos
for i, data in combos.items():
    data["words"] = data["words"].split(", ")
    data["words"] = [word.strip() for word in data["words"]]
    # data["words"].append(data["words"][0][1:])
combos
# Out:
# {1: {'words': ['Aat',
#    'Bat',
#    'Cat',
#    'Dat',
#    'Eat',
#    'Fat',
#    'Gat',
#    'Hat',
#    'Iat',
#    'Jat',
#    'Kat',
#    'Lat',
#    'Mat']},
#  2: {'words': ['Aard',
#    'Bard',
#    'Card',
#    'Dard',
#    'Eard',
#    'Fard',
#    'Gard',
#    'Hard',
#    'Iard',
#    'Jard',
#    'Kard',
#    'Lard',
#    'Mard']},
#  3: {'words': ['Aorp',
#    'Borp',
#    'Corp',
#    'Dorp',
#    'Eorp',
#    'Forp',
#    'Gorp',
#    'Horp',
#    'Iorp',
#    'Jorp',
#    'Korp',
#    'Lorp',
#    'Morp']},
#  4: {'words': ['Aowj',
#    'Bowj',
#    'Cowj',
#    'Dowj',
#    'Eowj',
#    'Fowj',
#    'Gowj',
#    'Howj',
#    'Iowj',
#    'Jowj',
#    'Kowj',
#    'Lowj',
#    'Mowj']},
#  5: {'words': ['Aüs',
#    'Büs',
#    'Cüs',
#    'Düs',
#    'Eüs',
#    'Füs',
#    'Güs',
#    'Hüs',
#    'Iüs',
#    'Jüs',
#    'Küs',
#    'Lüs',
#    'Müs']},
#  6: {'words': ['Aōb',
#    'Bōb',
#    'Cōb',
#    'Dōb',
#    'Eōb',
#    'Fōb',
#    'Gōb',
#    'Hōb',
# ...

# %%
# modifiers = {
#     "ā" : ["a","eigh","aigh","ay","ei","ei","au","ea"],
#     "ē" : ["e","ea","y","ey","ie","i","ei","eo"],
#     "ī" : ["y","igh","ie","uy","ai","i","ei","eo"],
#     "ō" : ["o-e","o","oe","ow",],
#     "ü" : ["ew","ue","oe","u-e","ough","ui","ou","eu","eau"],
# }

modifiers = {
    "ā" : ["eigh","aigh","ay","au"],
    "ē" : ["ey","ie","ee"],
    "ī" : ["igh","uy","ai"],
    "ō" : ["oa",],
    "ü" : ["ew","ue","ui","eu"],
}

modifiers.keys()
# Out:
# dict_keys(['ā', 'ē', 'ī', 'ō', 'ü'])

# %%
def generate_alternatives(word, special_char, mods):
    modified_words = []
    for mod in mods:
        modified_words.append(word.replace(special_char, mod))
    return modified_words

for rank, data in combos.items():
    words = data["words"]
    temp_words = []
    for char, mods in modifiers.items():
        if char in words[0]:
            for word in words:
                temp_words.extend(generate_alternatives(word, char, mods))
    words.extend(temp_words)

# %%
import enchant
import pandas as pd

# Create an English dictionary to check words against
d = enchant.Dict("en_US")

# Check each line to see if it's a real word
for rank, data in combos.items():
    words = data["words"]
    data["real_words"] = []
    for word in data["words"]:    
        word = word.strip() # Remove any leading/trailing whitespace
        # Check if the word is in the dictionary
        if d.check(word):
            data["real_words"].append(word)
        else:
            pass

# %%
for rank, data in combos.items():
    print(f"{' '.join(data['real_words'])}")
# Out:
# 1	Bat Cat Eat Fat Hat Lat Mat
# 2	Bard Card Hard Lard
# 3	Corp Gorp
# 4
# 5	Cues Dues Hews Hues Jews Luis Mews
# 6	Bōb Cōb Dōb Fōb Gōb Hōb Jōb Lōb Mōb
# 7
# 8	Star
# 9	Eēk Geek Leek Meek
# 10
# 11	Stow
# 12	Bad Cad Dad Fad Gad Had Lad Mad
# 13	Stew
# 14	Bap Cap Gap Hap Jap Lap Map
# 15	Haj Maj
# 16	Odor
# 17	Bāg Dāg Fāg Gāg Hāg Jāg Lāg Māg
# 18
# 19	Gas Has Las Mas
# 20
# 21
# 22
# 23	Carp Earp Harp
# 24	Rtē Stē Utē
# 25	Cab Dab Fab Gab Jab Lab
# 26
# 27	Jul
# 28
# 29
# 30	Stu
# 31	Stā Stay
# 32
# 33	Bars Cars Ears Gars Jars Lars Mars
# 34	Spew
# 35
# 36
# 37
# 38
# 39
# 40	Barb Garb
# 41	Cal Gal Hal
# 42	Bag Dag Fag Gag Hag Jag Lag Mag
# 43
# 44	Odē
# 45
# 46	Rte Ste Ute
# 47
# 48	Cor For
# 49	Bar Car Ear Far Gar Jar Mar
# 50
# 51	Barf
# 52
# 53	Cam Dam Ham Jam Lam Mam
# 54
# 55
# 56
# 57	Bows Cows Hows Lows Mows
# 58	Bark Dark Hark Lark Mark
# 59	Ban Can Dan Fan Han Ian Jan Kan Man
# 60
# 61	Opē
# 62
# 63
# 64
# 65
# 66	Aim Dim Him Jim Kim
# 67	Spā Spay
# 68
# ...
